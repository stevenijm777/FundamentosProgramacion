# %%
cadena = "jOse aNdRAde"
stirng = cadena.capitalize()
stirng
# Out:
# 'Jose andrade'

# %%
#Estudiante: Gabriela Alvarado Solis.
'''
print('Ejercicio 1'.center(50,"-"))
edad = int(input('Ingrese su edad: '))
altura = float(input('Ingrese su altura en m: '))
peso = float(input('Ingrese su peso en kg: '))
calorias_totales = 10*peso + 6.25*altura-5*edad+5
print(calorias_totales)
calorias_proteinas = calorias_totales*30//100
calorias_grasa = calorias_totales*25//100
calorias_carbohidratos = calorias_totales*45//100
print('Usted deberia comer: \n {} calorias de grasa \n {} calorias de proteinas \n {} calorias calorias_carbohidratos '.format(calorias_grasa,calorias_proteinas,calorias_carbohidratos))
print()
print('Ejercicio 2'.center(50,"-"))
'''
#ejercicio 2
# ejercicio 2
#inicializar la variable de la condicion
datos = input('Ingresa el paquete (peso,urgencia,confirmacion): ') # 10.5,normal,no
l_paguetes = [] # elprecio de cada paquete 
lista_paquetes = []
while not(datos == "x"):
  peso,estado,confirmacion = datos.split(",")
  peso = float(peso)#20
  estado = estado.lower()
  confirmacion = confirmacion.lower()
   
  costo=0
  if peso >= 10:
    costo += peso*6
  elif peso>=0 and peso<10:
    costo=peso*5
  elif peso>=100:
    print("paquete muy pesado")
    continue
  if estado == "urgente":
    num = costo *35/100 
    costo+= num
  if confirmacion == "si":
    costo+=10
  print("El costos de envio de ese paquete es de {}".format(costo))
  datos = input('Ingresa el paquete (peso,urgencia,confirmacion): ')
  
  if paquete  not in peso:
    lista_paquetes.append(paquete)

    print(lista_paquetes[::-1])
    print('Los paquetes mas caros son {}'.format(lista_paquetes[-1:-4]))
        
# muestres los paquetes ordenados por el peso
# los tres paquetes más caros




'''
#ejercicio 3
print()
print('Ejercicio 3'.center(50,"-"))
informacion = input('Ingrese su numero de tarjeta, su nombre y apellido, fecha de caducidad(mm/aa),codigo de seguridad: ')
#5312567895123487,JuAniTA ArcOS,12/03,123
info = []
info.append(informacion)

condicion1 = '16'
condicion2 = '15'
visa = '4'
mastercard1 = ['51','52','53','54','55']
dinersclub1 = '36'
dinersclub2 = '38'
discover1 = '60'
discover2 = '65'
american_express1 = '34'
american_express2 = '37'
print()
#print(info) #['2342233,gabriela alvarado,03/12,1232']
for elem in info:
  num_tarjeta,usuario,fecha,codigo = elem.split(',')
  nombre,apellido = usuario.split(' ')
  nombre = nombre.capitalize()
  apellido = apellido.capitalize()
  fecha = fecha.replace('/','-')
  #num_tarjeta = int(num_tarjeta)
  validacion = len(num_tarjeta)
  validacion = str(validacion)
  
  print('Datos Tarjeta: ')
  print('Numero de tarjeta: {}'.format(num_tarjeta))
  print('Nombre: {}'.format(nombre))
  print('Apellido: {}'.format(apellido))
  print('Fecha de caducidad: {}'.format(fecha))
  print('Codigo de seguridad: {}'.format(codigo))
if validacion == condicion1 or validacion== condicion2:
  if num_tarjeta[0] == visa: #
    print('Tipo: Visa')
  elif num_tarjeta [0:2] == dinersclub1 or num_tarjeta[0:2] == dinersclub2:
    print('Tipo: Disner Club')
  elif num_tarjeta [0:4] == discover1 or num_tarjeta [0:2] == discover2:
    print('Tipo: Discover')
  elif num_tarjeta [0:2] == american_express1 or num_tarjeta [0:2] == american_express2:
    print('Tipo: American Express ')
  else:
    for num in mastercard1:
      if num_tarjeta[0:2] == num:
        print('Tipo: Mastercard')
'''

# %% [markdown]
# **Ejercicio 2**
#
# Tenemos que manejar los paquetes de una empresa de correo. Debes escribir un programa que nos permita clasificar paquetes.
# Para esto, le vas a pedir al usuario que ingrese el peso del paquete, la urgencia (normal o urgente)
# y la confirmacion de entrega (si o no), separado por comas. La urgencia puede ser el string **urgente** o el string
# **normal** Pide los paquetes hasta que el usuario ingrese X. De acuerdo al peso y urgencia, vas a determinar el costo de envío.
# Las condiciones son:
#
# 1. Si el paquete pesa más de 10 kilos, el precio por kilo es $6.
# 2. Si el paquete pesa entre 0 kilos y menos de 10 kilos, el costos de envio es $5 por kilo.
# 3. Si el paquete es urgente, suma 35% al costo de envió.
# 4. No se envían paquetes de mas de 100 kilos. Mostrar el mensaje “Paquete muy pesados"
# 5. Si se desea confirmacion de entrega, añade $10 al costo de envio
#
# Cada vez que pidas un paquete, muestrale al usuario el costos de envio. Al final del programa muestra el total de costos de envio, y el total de peso. Por ejemplo:
#
# ```
# Ingresa el paquete (peso,urgencia,confirmacion):  10.5,normal,no
# El costos de envio de ese paquete es de $63.00
# Ingresa el paquete (peso,urgencia,confirmacion):  22,urgente,si
# El costos de envio de ese paquete es de $188.20
# Ingresa el paquete (peso,urgencia,confirmacion):  250,normal,no
# Paquete muy pesado.
# Ingresa el paquete (peso,urgencia,confirmacion):  x
# TOTAL: $251.20
#
# ```

# %%
# ejercicio 2
#inicializar la variable de la condicion
datos = input('Ingresa el paquete (peso,urgencia,confirmacion): ') # 10.5,normal,no
l_paguetes = [] # elprecio de cada paquete 
while not(datos == "x"):
    peso,estado,confirmacion = datos.split(",")
    peso = float(peso)#20
    estado = estado.lower()
    confirmacion = confirmacion.lower()
    costo=0
    if peso >= 10:
        costo += peso*6
    elif peso>=0 an peso<10:
        costo=peso*5
    elif peso>=100:
        print("paquete muy pesado")
        continue
    if estado == "urgente":
        num = costo *35/100 
        costo+= num
    if confirmacion == "si":
        costo+=10
    print("El costos de envio de ese paquete es de {}".format(costo))
    datos = input('Ingresa el paquete (peso,urgencia,confirmacion): '
        
# muestres los paquetes ordenados por el peso
# los tres paquetes más caros

# %%
#ejercicio 2
datos = input('Ingrese el peso del paquete en kilos,es urgente/normal, confirmacion de entrega Si/No : ')
lista_datos = []
lista_datos.append(datos)
for  i in lista_datos:
  peso,estado,confirmacion= i.split(',')
  peso = float(peso)
  estado = estado.lower()
  confirmacion = confirmacion.lower()
  
  
condicion = 'X'
while not (condicion=="X"):
  if peso > 10:
    precio_kilo = 6
  elif peso>0 and peso<10:
    costo_envio_kilo = 5
    print('El costo de envio de ese paquete es : {}'.format(costo_envio_kilo))
  elif estado == 'urgente':
    adicional = costo_envio_kilo * 35//100
    costo = costo_envio_kilo +adicional
  elif peso > 100:
    print('No se envian paquetes muy pesados')
  elif confirmacion == 'si':
     adicional_conf = costo_envio_kilo+100

# %%
# Taller 1

**Ejercicio 1**

Escribe un programa en Python que **pida** al usuario su edad, altura y peso y **muestre** cuantas calorías de proteína, grasa y carbohidratos necesita, de acuerdo a su peso y edad.  

                calorias totales = 10*peso + 6.25*altura – 5*edad + 5 

Peso en kilogramos, edad en años, altura en metro.

Porcentajes de calorias totales: 
* Porcentaje calorías proteínas = 30% de calorías totales 
* Porcentaje calorías grasas = 25 % de calorías totales 
* Porcentaje calorías carbohidratos = 45% de calorías totales 

Muestra un mensaje diciéndole al usuario cuantas calorías de grasa, proteína y carbohidratos debe comer. 


**Ejercicio 2**

Tenemos que manejar los paquetes de una empresa de correo. Debes escribir un programa que nos permita clasificar paquetes. Para esto, le vas a pedir al usuario que ingrese el peso del paquete, la urgencia (normal o urgente) y la confirmacion de entrega (si o no), separado por comas. La urgencia puede ser el string **urgente** o el string **normal** Pide los paquetes hasta que el usuario ingrese X. De acuerdo al peso y urgencia, vas a determinar el costo de envío. Las condiciones son: 

1. Si el paquete pesa más de 10 kilos, el precio por kilo es $6.
2. Si el paquete pesa entre 0 kilos y menos de 10 kilos, el costos de envio es $5 por kilo. 
3. Si el paquete es urgente, suma 35% al costo de envió.
4. No se envían paquetes de mas de 100 kilos. Mostrar el mensaje “Paquete muy pesados" 
5. Si se desea confirmacion de entrega, añade $10 al costo de envio

Cada vez que pidas un paquete, muestrale al usuario el costos de envio. Al final del programa muestra el total de costos de envio, y el total de peso. Por ejemplo:

```
Ingresa el paquete (peso,urgencia,confirmacion):  10.5,normal,no
El costos de envio de ese paquete es de $63.00
Ingresa el paquete (peso,urgencia,confirmacion):  22,urgente,si
El costos de envio de ese paquete es de $188.20
Ingresa el paquete (peso,urgencia,confirmacion):  250,normal,no
Paquete muy pesado.
Ingresa el paquete (peso,urgencia,confirmacion):  x
TOTAL: $251.20

```


**Ejercicio 3**

Escribe un programa en Python que pida un string con la información de una tarjeta de crédito, separada por comas, y luego la muestre con formato: 
Numero_tarjeta,nombre_apellido,fecha caducidad,código seguridad. Por ejemplo: 

                5545782067784200,jOse aNdRAde,04/23,778

Un ejemplo del programa:  

```
Ingrese la información: 5545782067784200,jose andrade,04/23,778 
 	
Datos Tarjeta: 
Número de tarjeta: 5545782067784200 
Nombre: José 
Apellido: Andrade 
Fecha caducidad: 04-2023 
Código de seguridad: 778 
Tipo: Mastercard
```

Para saber el tipo de tarjeta, usa las siguientes reglas:

* Visa, empiezan siempre con digito 4
* Mastercard tiene los dos primeros dígitos entre 51 y 55
* Diners Club empiezan con 36 o 38
* Discover empieza con 6011 o65
* American Express empiezan con 34 o 37

Debes validar que el numero de tarjeta sea válida. Un numero de tarjeta valido tiene 16 dígitos, salvo American Express que usan 15 dígitos.
